# %% [markdown]
# ## Isolation tests for business data to metric pipe; extraction.

# %% [markdown]
# ---
#
# 1. A direct polars query for talking to N companies, ALL metrics -- just printing business truth values in dataframe. no pipeline logic.
# 2. A simple call query; which calls metric pipeline, for a hypothetical BIG question- talking abt those 7-8 companies + ALL metrics, and generates snapshot text.

# %%
from pathlib import Path
import sys
import logging

logging.getLogger().setLevel(logging.WARNING)

current = Path.cwd()
for parent in [current] + list(current.parents):
    if parent.name == "ModelPipeline":
        model_root = parent
        break
else:
    raise RuntimeError("Cannot find 'ModelPipeline' root in path tree")

if str(model_root) not in sys.path:
    sys.path.insert(0, str(model_root))

print(f"✓ Model root on sys.path: {model_root}")
# Out:
# ✓ Model root on sys.path: d:\JoelDesktop folds_24\NEU FALL2025\MLops IE7374 Project\FinSights\ModelPipeline

# %%
## =================================================================================================
##  SUPPLY LINE 1: ENTITY-RESULT CHAINING. DEMO. Query → Extract Entities → Validate/Embed → Get KPI Data → Format → Display
## =================================================================================================

from pathlib import Path
import sys
import polars as pl

# 1. Put ModelPipeline on sys.path
current = Path.cwd()
for parent in [current] + list(current.parents):
    if parent.name == "ModelPipeline":
        model_root = parent
        break
else:
    raise RuntimeError("Cannot find 'ModelPipeline' root in path tree")
if str(model_root) not in sys.path:
    sys.path.insert(0, str(model_root))
print(f"✓ Model root on sys.path: {model_root}")


# Set maximum rows to display (None = unlimited)
pl.Config.set_tbl_rows(-1)  # or pl.Config.set_tbl_rows(None)

# Set maximum columns to display
pl.Config.set_tbl_cols(-1)

# Set maximum string column width (characters)
pl.Config.set_fmt_str_lengths(1000)  # or higher like 5000

# Set table width (total console width)
pl.Config.set_tbl_width_chars(2000)

# Optional: Set float precision for numeric display
pl.Config.set_float_precision(3)


## SUPPLY LINE 1: ENTITY-RESULT CHAINING. DEMO. Query → Extract Entities → Validate/Embed → Get KPI Data → Format → Display
from finrag_ml_tg1.rag_modules_src.utilities.supply_line_formatters import format_analytical_compact
from finrag_ml_tg1.rag_modules_src.metric_pipeline.src.pipeline import MetricPipeline
from finrag_ml_tg1.rag_modules_src.entity_adapter.entity_adapter import EntityAdapter

METRIC_DATA_JSON = model_root / "finrag_ml_tg1/rag_modules_src/metric_pipeline/data/downloaded_data.json"
DIM_COMPANIES = model_root / "finrag_ml_tg1/data_cache/dimensions/finrag_dim_companies_21.parquet"
DIM_SECTIONS = model_root / "finrag_ml_tg1/data_cache/dimensions/finrag_dim_sec_sections.parquet"
METRIC_DATA_FACT = model_root / "finrag_ml_tg1/rag_modules_src/metric_pipeline/data/KPI_FACT_DATA_EDGAR.parquet" 

metric_fact_data_schema = pl.read_parquet(METRIC_DATA_FACT).collect_schema()
metric_fact_data_schema
metric_fact_data = pl.read_parquet(METRIC_DATA_FACT)


dist_tickers = metric_fact_data.select(pl.col("ticker").unique()).sort("ticker")
dist_tickers
# dist_companies = metric_fact_data.select(pl.col("company_name").unique()).sort("company_name")



# MSFT NVDA GOOGLE COST AMZN 
target_companies = ["MSFT", "NVDA", "GOOGL", "COST", "AMZN"]

metrics_view_readable = (
    metric_fact_data
    .filter(
        pl.col("ticker").is_in(target_companies) &
        pl.col("year").is_between(2018, 2022)
    )
    .select(["ticker", "metric_key",
              #, "metric_code", "metric_gaap",
              "metric_label", "year", "value"])
    .with_columns([
        # Add human-readable formatted column
        pl.when(pl.col("value").abs() >= 1e9)
          .then((pl.col("value") / 1e9).round(2).cast(pl.Utf8) + "B")
        .when(pl.col("value").abs() >= 1e6)
          .then((pl.col("value") / 1e6).round(2).cast(pl.Utf8) + "M")
        .when(pl.col("value").abs() >= 1e3)
          .then((pl.col("value") / 1e3).round(2).cast(pl.Utf8) + "K")
        .otherwise(pl.col("value").round(2).cast(pl.Utf8))
        .alias("value_readable")
    ])
)

# metrics_view_readable
# Out:
# ✓ Model root on sys.path: d:\JoelDesktop folds_24\NEU FALL2025\MLops IE7374 Project\FinSights\ModelPipeline

# %%
# Query to get distinct values for all 4 metric columns - handling nulls
metric_columns_dict = {}

for col in ['metric_key', 'metric_code', 'metric_gaap', 'metric_label']:
    # Get unique values, filter out nulls, sort, join
    values = (
        metric_fact_data
        .select(col)
        .unique()
        .filter(pl.col(col).is_not_null())  # Remove nulls
        .to_series()
        .to_list()
    )
    metric_columns_dict[col] = ', '.join(sorted(values))

# Print each as comma-separated string
for col_name, values_str in metric_columns_dict.items():
    print(f"\n{'='*80}")
    print(f"{col_name.upper()}:")
    print(f"{'='*80}")
    print(values_str)
    print(f"\nCount: {len(values_str.split(', ')) if values_str else 0} unique values")
# Out:
# ================================================================================
# METRIC_KEY:
# ================================================================================
# amortization_year5, business_combination_liabilities, capex_intangibles, capex_net_productive, capex_productive, cfo, cfo_cont_ops, change_in_other_assets, debt_to_assets, debt_to_equity, deferred_taxes_other_current, derivative_liabilities_current, disposal_group_assets_current, disposal_group_gross_profit, disposal_group_liabilities_current, disposal_group_other_assets, disposal_group_other_liabilities, dta_capital_loss_cf, dta_deferred_income, dta_derivatives, dta_net, dta_nol, dta_nol_domestic, dta_nol_foreign, dta_nol_state_local, dta_oci_loss, dta_other, dta_ppe, dta_rnd, dta_unrealized_losses_afs, dtl_derivatives, dtl_goodwill_intangibles, dtl_investment_affiliates, dtl_ppe, dtl_undistributed_foreign, dtl_unrealized_gains_trading, employee_liabilities_current, employee_liabilities_total, equity, equity_incl_nci, equity_other, equity_other_shares, equity_stock_split, financial_asset_transfer, gross_profit, impairment_intangibles, impairment_long_lived_assets, intangibles_gross_excl_goodwill, liabilities_and_equity, misc_assets_noncurrent, net_income, net_income_common_basic, net_income_common_diluted, net_income_incl_nonredeemable_nci, net_income_lp_basic, net_income_lp_basic_diluted, net_income_nci, net_income_nonredeemable_nci, net_income_parent_diluted, net_income_redeemable_nci, net_profit_margin, noncash_liabilities_acquired, operating_margin, other_accrued_liabilities_current, other_assets_current, other_assets_fair_value, other_assets_noncurrent, other_liabilities, other_liabilities_fair_value, other_liabilities_noncurrent, other_sundry_liabilities, other_sundry_liabilities_noncurrent, pension_liabilities_noncurrent, pension_liabilities_total, prepaid_expenses_current, proceeds_asset_sale_investing, proceeds_business_sales, proceeds_from_asset_sales, revenue, revenue_gross, revenue_net, roa, roe, securities_loaned, segment_capex, separate_account_assets, share_based_liabilities_paid, tax_change_valuation_allowance, tax_rate_change_val_allowance, vie_assets, vie_assets_pledged, vie_liabilities, vie_liabilities_no_recourse, vie_nonconsolidated_assets
#
# Count: 94 unique values
#
# ================================================================================
# METRIC_CODE:
# ================================================================================
# us-gaap:AssetsOfDisposalGroupIncludingDiscontinuedOperationCurrent, us-gaap:BusinessCombinationRecognizedIdentifiableAssetsAcquiredAndLiabilitiesAssumedLiabilities, us-gaap:DeferredIncomeTaxAssetsNet, us-gaap:DeferredIncomeTaxesAndOtherAssetsCurrent, us-gaap:DeferredIncomeTaxesAndOtherLiabilitiesNoncurrent, us-gaap:DeferredTaxAndOtherLiabilitiesNoncurrent, us-gaap:DeferredTaxAssetsCapitalLossCarryforwards, us-gaap:DeferredTaxAssetsDeferredIncome, us-gaap:DeferredTaxAssetsDerivativeInstruments, us-gaap:DeferredTaxAssetsInProcessResearchAndDevelopment, us-gaap:DeferredTaxAssetsOperatingLossCarryforwards, us-gaap:DeferredTaxAssetsOperatingLossCarryforwardsDomestic, us-gaap:DeferredTaxAssetsOperatingLossCarryforwardsForeign, us-gaap:DeferredTaxAssetsOperatingLossCarryforwardsStateAndLocal, us-gaap:DeferredTaxAssetsOther, us-gaap:DeferredTaxAssetsOtherComprehensiveLoss, us-gaap:DeferredTaxAssetsPropertyPlantAndEquipment, us-gaap:DeferredTaxAssetsUnrealizedLossesOnAvailableforSaleSecuritiesGross, us-gaap:DeferredTaxLiabilitiesDerivatives, us-gaap:DeferredTaxLiabilitiesGoodwillAndIntangibleAssetsIntangibleAssets, us-gaap:DeferredTaxLiabilitiesInvestmentInNoncontrolledAffiliates, us-gaap:DeferredTaxLiabilitiesPropertyPlantAndEquipment, us-gaap:DeferredTaxLiabilitiesUndistributedForeignEarnings, us-gaap:DeferredTaxLiabilitiesUnrealizedGainsOnTradingSecurities, us-gaap:DerivativeLiabilitiesCurrent, us-gaap:DisposalGroupIncludingDiscontinuedOperationGrossProfitLoss, us-gaap:DisposalGroupIncludingDiscontinuedOperationOtherAssets, us-gaap:DisposalGroupIncludingDiscontinuedOperationOtherLiabilities, us-gaap:EffectiveIncomeTaxRateReconciliationChangeInDeferredTaxAssetsValuationAllowance, us-gaap:EmployeeRelatedLiabilitiesCurrent, us-gaap:EmployeeRelatedLiabilitiesCurrentAndNoncurrent, us-gaap:FiniteLivedIntangibleAssetsAmortizationExpenseYearFive, us-gaap:GrossProfit, us-gaap:ImpairmentOfIntangibleAssetsIndefinitelivedExcludingGoodwill, us-gaap:ImpairmentOfLongLivedAssetsHeldForUse, us-gaap:IncomeTaxReconciliationChangeInDeferredTaxAssetsValuationAllowance, us-gaap:IncreaseDecreaseInPrepaidDeferredExpenseAndOtherAssets, us-gaap:IntangibleAssetsGrossExcludingGoodwill, us-gaap:LiabilitiesAndStockholdersEquity, us-gaap:LiabilitiesOfDisposalGroupIncludingDiscontinuedOperationCurrent, us-gaap:NetCashProvidedByUsedInOperatingActivities, us-gaap:NetCashProvidedByUsedInOperatingActivitiesContinuingOperations, us-gaap:NetIncomeLoss, us-gaap:NetIncomeLossAttributableToNoncontrollingInterest, us-gaap:NetIncomeLossAttributableToNonredeemableNoncontrollingInterest, us-gaap:NetIncomeLossAttributableToParentDiluted, us-gaap:NetIncomeLossAttributableToRedeemableNoncontrollingInterest, us-gaap:NetIncomeLossAvailableToCommonStockholdersBasic, us-gaap:NetIncomeLossAvailableToCommonStockholdersDiluted, us-gaap:NetIncomeLossIncludingPortionAttributableToNonredeemableNoncontrollingInterest, us-gaap:NetIncomeLossPerOutstandingLimitedPartnershipAndGeneralPartnershipUnitBasicAndDiluted, us-gaap:NetIncomeLossPerOutstandingLimitedPartnershipUnitBasicNetOfTax, us-gaap:NoncashOrPartNoncashAcquisitionValueOfLiabilitiesAssumed1, us-gaap:OtherAccruedLiabilitiesCurrent, us-gaap:OtherAssetsCurrent, us-gaap:OtherAssetsFairValueDisclosure, us-gaap:OtherAssetsMiscellaneousNoncurrent, us-gaap:OtherAssetsNoncurrent, us-gaap:OtherLiabilities, us-gaap:OtherLiabilitiesFairValueDisclosure, us-gaap:OtherLiabilitiesNoncurrent, us-gaap:OtherSundryLiabilities, us-gaap:OtherSundryLiabilitiesNoncurrent, us-gaap:PaymentsForProceedsFromProductiveAssets, us-gaap:PaymentsToAcquireIntangibleAssets, us-gaap:PaymentsToAcquireProductiveAssets, us-gaap:PensionAndOtherPostretirementAndPostemploymentBenefitPlansLiabilitiesCurrentAndNoncurrent, us-gaap:PensionAndOtherPostretirementDefinedBenefitPlansLiabilitiesNoncurrent, us-gaap:PrepaidExpenseAndOtherAssetsCurrent, us-gaap:ProceedsFromSaleOfOtherAssetsInvestingActivities, us-gaap:ProceedsFromSaleOfProductiveAssets, us-gaap:ProceedsFromSalesOfBusiness ...
#
# Count: 90 unique values
#
# ================================================================================
# METRIC_GAAP:
# ================================================================================
# us-gaap:AssetsOfDisposalGroupIncludingDiscontinuedOperationCurrent, us-gaap:BusinessCombinationRecognizedIdentifiableAssetsAcquiredAndLiabilitiesAssumedLiabilities, us-gaap:DeferredIncomeTaxAssetsNet, us-gaap:DeferredIncomeTaxesAndOtherAssetsCurrent, us-gaap:DeferredIncomeTaxesAndOtherLiabilitiesNoncurrent, us-gaap:DeferredTaxAndOtherLiabilitiesNoncurrent, us-gaap:DeferredTaxAssetsCapitalLossCarryforwards, us-gaap:DeferredTaxAssetsDeferredIncome, us-gaap:DeferredTaxAssetsDerivativeInstruments, us-gaap:DeferredTaxAssetsInProcessResearchAndDevelopment, us-gaap:DeferredTaxAssetsOperatingLossCarryforwards, us-gaap:DeferredTaxAssetsOperatingLossCarryforwardsDomestic, us-gaap:DeferredTaxAssetsOperatingLossCarryforwardsForeign, us-gaap:DeferredTaxAssetsOperatingLossCarryforwardsStateAndLocal, us-gaap:DeferredTaxAssetsOther, us-gaap:DeferredTaxAssetsOtherComprehensiveLoss, us-gaap:DeferredTaxAssetsPropertyPlantAndEquipment, us-gaap:DeferredTaxAssetsUnrealizedLossesOnAvailableforSaleSecuritiesGross, us-gaap:DeferredTaxLiabilitiesDerivatives, us-gaap:DeferredTaxLiabilitiesGoodwillAndIntangibleAssetsIntangibleAssets, us-gaap:DeferredTaxLiabilitiesInvestmentInNoncontrolledAffiliates, us-gaap:DeferredTaxLiabilitiesPropertyPlantAndEquipment, us-gaap:DeferredTaxLiabilitiesUndistributedForeignEarnings, us-gaap:DeferredTaxLiabilitiesUnrealizedGainsOnTradingSecurities, us-gaap:DerivativeLiabilitiesCurrent, us-gaap:DisposalGroupIncludingDiscontinuedOperationGrossProfitLoss, us-gaap:DisposalGroupIncludingDiscontinuedOperationOtherAssets, us-gaap:DisposalGroupIncludingDiscontinuedOperationOtherLiabilities, us-gaap:EffectiveIncomeTaxRateReconciliationChangeInDeferredTaxAssetsValuationAllowance, us-gaap:EmployeeRelatedLiabilitiesCurrent, us-gaap:EmployeeRelatedLiabilitiesCurrentAndNoncurrent, us-gaap:FiniteLivedIntangibleAssetsAmortizationExpenseYearFive, us-gaap:GrossProfit, us-gaap:ImpairmentOfIntangibleAssetsIndefinitelivedExcludingGoodwill, us-gaap:ImpairmentOfLongLivedAssetsHeldForUse, us-gaap:IncomeTaxReconciliationChangeInDeferredTaxAssetsValuationAllowance, us-gaap:IncreaseDecreaseInPrepaidDeferredExpenseAndOtherAssets, us-gaap:IntangibleAssetsGrossExcludingGoodwill, us-gaap:LiabilitiesAndStockholdersEquity, us-gaap:LiabilitiesOfDisposalGroupIncludingDiscontinuedOperationCurrent, us-gaap:NetCashProvidedByUsedInOperatingActivities, us-gaap:NetCashProvidedByUsedInOperatingActivitiesContinuingOperations, us-gaap:NetIncomeLoss, us-gaap:NetIncomeLossAttributableToNoncontrollingInterest, us-gaap:NetIncomeLossAttributableToNonredeemableNoncontrollingInterest, us-gaap:NetIncomeLossAttributableToParentDiluted, us-gaap:NetIncomeLossAttributableToRedeemableNoncontrollingInterest, us-gaap:NetIncomeLossAvailableToCommonStockholdersBasic, us-gaap:NetIncomeLossAvailableToCommonStockholdersDiluted, us-gaap:NetIncomeLossIncludingPortionAttributableToNonredeemableNoncontrollingInterest, us-gaap:NetIncomeLossPerOutstandingLimitedPartnershipAndGeneralPartnershipUnitBasicAndDiluted, us-gaap:NetIncomeLossPerOutstandingLimitedPartnershipUnitBasicNetOfTax, us-gaap:NoncashOrPartNoncashAcquisitionValueOfLiabilitiesAssumed1, us-gaap:OtherAccruedLiabilitiesCurrent, us-gaap:OtherAssetsCurrent, us-gaap:OtherAssetsFairValueDisclosure, us-gaap:OtherAssetsMiscellaneousNoncurrent, us-gaap:OtherAssetsNoncurrent, us-gaap:OtherLiabilities, us-gaap:OtherLiabilitiesFairValueDisclosure, us-gaap:OtherLiabilitiesNoncurrent, us-gaap:OtherSundryLiabilities, us-gaap:OtherSundryLiabilitiesNoncurrent, us-gaap:PaymentsForProceedsFromProductiveAssets, us-gaap:PaymentsToAcquireIntangibleAssets, us-gaap:PaymentsToAcquireProductiveAssets, us-gaap:PensionAndOtherPostretirementAndPostemploymentBenefitPlansLiabilitiesCurrentAndNoncurrent, us-gaap:PensionAndOtherPostretirementDefinedBenefitPlansLiabilitiesNoncurrent, us-gaap:PrepaidExpenseAndOtherAssetsCurrent, us-gaap:ProceedsFromSaleOfOtherAssetsInvestingActivities, us-gaap:ProceedsFromSaleOfProductiveAssets, us-gaap:ProceedsFromSalesOfBusiness ...
#
# Count: 90 unique values
#
# ================================================================================
# METRIC_LABEL:
# ================================================================================
# Amortization Expense – Year 5, Business Combination – Liabilities Assumed, Change in Other Assets, Current Assets – Disposal Group, Current Liabilities – Disposal Group, Debt-to-Assets, Debt-to-Equity, Deferred Income Tax Assets – Net, Deferred Income Taxes And Other Liabilities Noncurrent, Deferred Tax And Other Liabilities Noncurrent, Deferred Tax Asset Valuation Allowance Change, Deferred Tax Assets – Capital Loss CF, Deferred Tax Assets – Deferred Income, Deferred Tax Assets – Derivatives, Deferred Tax Assets – IPR&D, Deferred Tax Assets – NOL, Deferred Tax Assets – NOL Domestic, Deferred Tax Assets – NOL Foreign, Deferred Tax Assets – NOL State/Local, Deferred Tax Assets – OCI Loss, Deferred Tax Assets – Other, Deferred Tax Assets – PPE, Deferred Tax Assets – Unrealized Losses (AFS), Deferred Tax Liabilities – Derivatives, Deferred Tax Liabilities – Goodwill & Intangibles, Deferred Tax Liabilities – Noncontrolled Affiliates, Deferred Tax Liabilities – PPE, Deferred Tax Liabilities – Undistributed Foreign Earnings, Deferred Tax Liabilities – Unrealized Gains (Trading), Deferred Taxes & Other Assets (Current), Derivative Liabilities (Current), Employee-Related Liabilities (Current), Employee-Related Liabilities (Total), Equity Including NCI, Equity – Stock Split Conversion, Financial Asset Transfers Derecognized, Gross Profit, Gross Profit (Disposal Group), Gross Revenue, Impairment – Indefinite-Lived Intangibles, Impairment – Long-Lived Assets, Intangible Assets (Gross, Excluding Goodwill), Liabilities & Stockholders’ Equity, Miscellaneous Assets (Noncurrent), Net Income, Net Income Attributable to Parent – Diluted, Net Income Available to Common – Basic, Net Income Available to Common – Diluted, Net Income per LP Unit (Basic & Diluted), Net Income per LP Unit (Basic), Net Income – Including Nonredeemable NCI, Net Income – Noncontrolling Interest, Net Income – Nonredeemable NCI, Net Income – Redeemable NCI, Net Payments/Proceeds – Productive Assets, Net Profit Margin %, Net Revenue, Non-cash Liabilities Assumed, Operating Cash Flow, Operating Cash Flow – Continuing Ops, Operating Margin %, Other Accrued Liabilities (Current), Other Assets (Noncurrent), Other Assets – Disposal Group, Other Assets – Fair Value, Other Current Assets, Other Equity Shares, Other Liabilities, Other Liabilities (Noncurrent), Other Liabilities – Disposal Group, Other Liabilities – Fair Value, Other Stockholders’ Equity, Other Sundry Liabilities, Other Sundry Liabilities (Noncurrent), Payments to Acquire Intangible Assets, Payments to Acquire Productive Assets, Pension & Benefit Liabilities (Total), Pension & Postretirement Liabilities – Noncurrent, Prepaid Expenses (Current), Proceeds from Other Asset Sales (Investing), Proceeds from Productive Asset Sales, Proceeds from Sale of Businesses / Assets, ROA % (Avg Assets), ROE % (Avg Equity), Revenue, Securities Loaned, Segment Additions to Long-Lived Assets, Separate Account Assets, Share-based Payment Liabilities Paid, Stockholders’ Equity, Tax Rate – Change in Valuation Allowance, VIE Assets Pledged, VIE Consolidated Assets, VIE Consolidated Liabilities, VIE Liabilities (No Recourse), VIE Non-consolidated Assets
#
# Count: 97 unique values

# %%
# # MSFT NVDA GOOGLE COST AMZN 
# target_companies = ["MSFT", "NVDA", "GOOGL", "COST", "AMZN"]

# metrics_view_readable = (
#     metric_fact_data
#     .filter(
#         pl.col("ticker").is_in(target_companies) &
#         pl.col("year").is_between(2018, 2022)
#     )
#     .select(["ticker", "metric_key", "metric_label", "year", "value"])
#     .with_columns([
#         # Add human-readable formatted column
#         pl.when(pl.col("value").abs() >= 1e9)
#           .then((pl.col("value") / 1e9).round(2).cast(pl.Utf8) + "B")
#         .when(pl.col("value").abs() >= 1e6)
#           .then((pl.col("value") / 1e6).round(2).cast(pl.Utf8) + "M")
#         .when(pl.col("value").abs() >= 1e3)
#           .then((pl.col("value") / 1e3).round(2).cast(pl.Utf8) + "K")
#         .otherwise(pl.col("value").round(2).cast(pl.Utf8))
#         .alias("value_readable")
#     ])
# )

# # metrics_view_readable

# metric_fact_data

# dist_metrickey = metric_fact_data.select(pl.col("metric_key").unique()).sort("metric_key")
# dist_metrickey

# %%
"""

"total sales" → revenue
"bottom line profits" → net_income
"operating cash flows" → cfo (Operating Cash Flow)
"gross margins" → gross_profit_margin (ratio metric)
"total debt levels" → debt_to_assets or total liabilities
"shareholder equity" → equity
"cost of goods sold" → cogs (Cost of Revenue)
"tax expenses" → tax (Provision for Income Tax)
"return on assets" → roa
"earnings per share" → eps (needs mapping if available)

"""
# Out:
# '\n\n"total sales" → revenue\n"bottom line profits" → net_income\n"operating cash flows" → cfo (Operating Cash Flow)\n"gross margins" → gross_profit_margin (ratio metric)\n"total debt levels" → debt_to_assets or total liabilities\n"shareholder equity" → equity\n"cost of goods sold" → cogs (Cost of Revenue)\n"tax expenses" → tax (Provision for Income Tax)\n"return on assets" → roa\n"earnings per share" → eps (needs mapping if available)\n\n'

# %%
def debug_print_entities_and_metrics(query, entities, metric_result):
    print("\n" + "="*80)
    print("QUERY")
    print("="*80)
    print(query)

    # ---------- EntityAdapter result ----------
    print("\n[ENTITY EXTRACTION]")
    companies = ", ".join(entities.companies.tickers) or "(none)"
    years     = ", ".join(str(y) for y in entities.years.years) or "(none)"
    sections  = ", ".join(entities.sections) or "(none)"

    # metrics from EntityAdapter; each entry is usually a MetricCandidate
    metric_list = []
    if getattr(entities, "metrics", None) and getattr(entities.metrics, "metrics", None):
        for m in entities.metrics.metrics:
            metric_id = getattr(m, "metric_id", None) or getattr(m, "metric_name", None) or str(m)
            metric_list.append(metric_id)
    metrics = ", ".join(metric_list) if metric_list else "(none)"

    print(f"  Companies: {companies}")
    print(f"  Years:     {years}")
    print(f"  Sections:  {sections}")
    print(f"  Metrics:   {metrics}")

    # ---------- MetricPipeline result ----------
    print("\n[METRIC PIPELINE FILTERS]")
    if metric_result.get("success"):
        f = metric_result.get("filters", {})
        f_tickers = ", ".join(f.get("tickers", [])) or "(none)"
        f_years   = ", ".join(str(y) for y in f.get("years", [])) or "(none)"
        f_metrics = ", ".join(f.get("metrics", [])) or "(none)"

        print(f"  Tickers: {f_tickers}")
        print(f"  Years:   {f_years}")
        print(f"  Metrics: {f_metrics}")
        print(f"  Records returned: {metric_result.get('count', 0)}")
    else:
        reason = metric_result.get("reason", "metric layer not activated")
        print(f"  Status: {reason}")
        if "extracted_filters" in metric_result:
            ef = metric_result["extracted_filters"]
            ef_tickers = ", ".join(ef.get("tickers", [])) or "(none)"
            ef_years   = ", ".join(str(y) for y in ef.get("years", [])) or "(none)"
            ef_metrics = ", ".join(ef.get("metrics", [])) or "(none)"
            print(f"  Extracted (pre-check): tickers={ef_tickers}, years={ef_years}, metrics={ef_metrics}")



## =================================================================================================
##  SUPPLY LINE 1: ENTITY-RESULT CHAINING. DEMO. Query → Extract Entities → Validate/Embed → Get KPI Data → Format → Display
""" query = "In the MD&A and Risk Factors sections, how did NVIDIA and Microsoft discuss their AI strategy, competitive positioning, and supply chain risks between 2020 and 2023?"
"""
## =================================================================================================

from pathlib import Path
import sys

# 1. Put ModelPipeline on sys.path
current = Path.cwd()
for parent in [current] + list(current.parents):
    if parent.name == "ModelPipeline":
        model_root = parent
        break
else:
    raise RuntimeError("Cannot find 'ModelPipeline' root in path tree")
if str(model_root) not in sys.path:
    sys.path.insert(0, str(model_root))
print(f"✓ Model root on sys.path: {model_root}")


## SUPPLY LINE 1: ENTITY-RESULT CHAINING. DEMO. Query → Extract Entities → Validate/Embed → Get KPI Data → Format → Display
from finrag_ml_tg1.rag_modules_src.utilities.supply_line_formatters import format_analytical_compact
from finrag_ml_tg1.rag_modules_src.metric_pipeline.src.pipeline import MetricPipeline
from finrag_ml_tg1.rag_modules_src.entity_adapter.entity_adapter import EntityAdapter

METRIC_DATA_JSON = model_root / "finrag_ml_tg1/rag_modules_src/metric_pipeline/data/downloaded_data.json"
DIM_COMPANIES = model_root / "finrag_ml_tg1/data_cache/dimensions/finrag_dim_companies_21.parquet"
DIM_SECTIONS = model_root / "finrag_ml_tg1/data_cache/dimensions/finrag_dim_sec_sections.parquet"

METRIC_DATA_FACT = model_root / "finrag_ml_tg1/rag_modules_src/metric_pipeline/data/KPI_FACT_DATA_EDGAR.parquet" 


adapter =  EntityAdapter( company_dim_path=DIM_COMPANIES, section_dim_path=DIM_SECTIONS )

metric_pipeline = MetricPipeline(data_path=str(METRIC_DATA_FACT), company_dim_path=str(DIM_COMPANIES))


# ## need to quickly access entities. -> and metric process.-> whatever years, sections, companies, etc. have been extracted.
# debug_print_entities_and_metrics(query, entities, result)

query = (
    "Show me Apple, Microsoft, Amazon, Alphabet, Google, and Tesla's financial performance "
    "from 2018 to 2022. I need their total sales, bottom line profits, "
    "operating cash flows, gross margins, total debt levels, shareholder equity, "
    "cost of goods sold, tax expenses, return on assets, and earnings per share. "
    "How did these companies explain their revenue growth and profitability trends "
    "in their MD&A sections, and what supply chain or competitive risks did they "
    "highlight in their Risk Factors?"
)
entities = adapter.extract(query)
result = metric_pipeline.process(query)

entity_meta = { "companies": list(entities.companies.tickers), "years": list(entities.years.years), "sections": list(entities.sections), }
compact = format_analytical_compact(result, entity_meta=entity_meta)

print("\n" + "="*80)
print("SUPPLY LINE 1 – KPI SNAPSHOT")
print("="*80)
print(compact or "(no KPI data returned)")


print("\n" + "="*80)
print("DEBUG: RESULT OBJECT")
print("="*80)
print(f"Success: {result.get('success')}")
print(f"Count: {result.get('count')}")
print(f"Has 'data' key: {'data' in result}")
if 'data' in result:
    print(f"Data length: {len(result['data'])}")
    print(f"First record: {result['data'][0] if result['data'] else 'EMPTY'}")
print("="*80)


## debug now.
debug_print_entities_and_metrics(query, entities, result)
# Out:
# ✓ Model root on sys.path: d:\JoelDesktop folds_24\NEU FALL2025\MLops IE7374 Project\FinSights\ModelPipeline
# ✓ FilterExtractor initialized with 21 companies
#   Using: finrag_dim_companies_21.parquet
# ✓ FilterExtractor initialized with 21 companies
#   Using: finrag_dim_companies_21.parquet
# ✓ Loaded 3,714 records from KPI_FACT_DATA_EDGAR.parquet (20 tickers, 2016-2025)
#
# ================================================================================
# SUPPLY LINE 1 – KPI SNAPSHOT
# ================================================================================
# ══════════════════════════════════════════════════════════════════════
# KPI SNAPSHOT - METRIC PIPELINE OUTPUT
# ══════════════════════════════════════════════════════════════════════
#
# Scope:
#   Companies (entities): AAPL, AMZN, GOOGL, MSFT, TSLA
#   Years (entities):     2018, 2019, 2020, 2021, 2022
#   Sections (entities):  ITEM_1A, ITEM_7
#   Companies (metrics):  AAPL, AMZN, GOOGL, MSFT, TSLA
#   Years (metrics):      2018, 2019, 2020, 2021, 2022
#   Metrics:              Operating Cash Flow, Stockholders' Equity, Gross Profit, Debt-to-Assets, ROA % (Avg Assets), Revenue, Net Income
#   Coverage:             109/175 metric combinations with values
#
# DETAILS BY COMPANY AND YEAR
#
# AAPL:
#   2018: Operating Cash Flow=$77.4B, Gross Profit=$24.1B, Debt-to-Assets=0.71, ROA % (Avg Assets)=16.9%, Revenue=$62.9B, Net Income=$14.1B
#   2019: Operating Cash Flow=$69.4B, Gross Profit=$24.3B, Debt-to-Assets=0.73, ROA % (Avg Assets)=16.7%, Net Income=$13.7B
#   2020: Operating Cash Flow=$80.7B, Gross Profit=$24.7B, Debt-to-Assets=0.80, ROA % (Avg Assets)=17.0%, Net Income=$12.7B
#   2021: Operating Cash Flow=$104.0B, Gross Profit=$152.8B, Debt-to-Assets=0.82, ROA % (Avg Assets)=26.9%, Net Income=$94.7B
#   2022: Operating Cash Flow=$122.2B, Gross Profit=$170.8B, Debt-to-Assets=0.86, ROA % (Avg Assets)=28.3%, Net Income=$99.8B
#
# AMZN:
#   2018: Operating Cash Flow=$30.7B, ROA % (Avg Assets)=5.2%, Net Income=$3.0B
#   2019: Operating Cash Flow=$38.5B, ROA % (Avg Assets)=4.2%, Net Income=$3.3B
#   2020: Operating Cash Flow=$66.1B, ROA % (Avg Assets)=5.8%, Net Income=$7.2B
#   2021: Operating Cash Flow=$46.3B, ROA % (Avg Assets)=7.6%, Net Income=$33.4B
#   2022: Operating Cash Flow=$46.8B, ROA % (Avg Assets)=-0.5%, Net Income=$-2.7B
#
# GOOGL:
#   2018: Operating Cash Flow=$48.0B, Debt-to-Assets=0.24, ROA % (Avg Assets)=12.1%, Net Income=$30.7B
#   2019: Operating Cash Flow=$54.5B, Debt-to-Assets=0.27, ROA % (Avg Assets)=11.5%, Net Income=$34.3B
#   2020: Operating Cash Flow=$65.1B, Debt-to-Assets=0.30, ROA % (Avg Assets)=11.9%, Revenue=$182.5B, Net Income=$40.3B
#   2021: Operating Cash Flow=$91.7B, Debt-to-Assets=0.30, ROA % (Avg Assets)=21.0%, Revenue=$257.6B, Net Income=$76.0B
#   2022: Operating Cash Flow=$91.5B, Debt-to-Assets=0.30, ROA % (Avg Assets)=15.6%, Net Income=$60.0B
#
# MSFT:
#   2018: Operating Cash Flow=$43.9B, Gross Profit=$20.3B, Debt-to-Assets=0.68, ROA % (Avg Assets)=6.1%, Net Income=$8.9B
#   2019: Operating Cash Flow=$52.2B, Gross Profit=$23.3B, Debt-to-Assets=0.64, ROA % (Avg Assets)=13.3%, Net Income=$13.2B
#   2020: Operating Cash Flow=$60.7B, Gross Profit=$25.7B, Debt-to-Assets=0.61, ROA % (Avg Assets)=13.9%, Net Income=$11.2B
#   2021: Operating Cash Flow=$76.7B, Gross Profit=$115.9B, Debt-to-Assets=0.57, ROA % (Avg Assets)=17.5%, Net Income=$61.3B
#   2022: Operating Cash Flow=$89.0B, Gross Profit=$135.6B, Debt-to-Assets=0.54, ROA % (Avg Assets)=18.7%, Net Income=$72.7B
#
# TSLA:
#   2018: Operating Cash Flow=$2.1B, Gross Profit=$1.4B, Revenue=$7.2B
#   2019: Operating Cash Flow=$2.4B, Gross Profit=$1.4B, Revenue=$7.4B
#   2020: Operating Cash Flow=$5.9B, Gross Profit=$2.1B, Debt-to-Assets=0.54, ROA % (Avg Assets)=1.3%, Revenue=$10.7B
#   2021: Operating Cash Flow=$11.5B, Gross Profit=$13.6B, Debt-to-Assets=0.49, ROA % (Avg Assets)=7.6%, Revenue=$53.8B
#   2022: Operating Cash Flow=$14.7B, Gross Profit=$20.9B, Debt-to-Assets=0.44, ROA % (Avg Assets)=13.3%, Revenue=$81.5B
#
#
# ================================================================================
# DEBUG: RESULT OBJECT
# ================================================================================
# Success: True
# Count: 109
# Has 'data' key: True
# Data length: 109
# First record: {'ticker': 'TSLA', 'year': 2018, 'metric_label': 'Revenue', 'value': 7225873000.0, 'found': True}
# ================================================================================
#
# ================================================================================
# QUERY
# ================================================================================
# Show me Apple, Microsoft, Amazon, Alphabet, Google, and Tesla's financial performance from 2018 to 2022. I need their total sales, bottom line profits, operating cash flows, gross margins, total debt levels, shareholder equity, cost of goods sold, tax expenses, return on assets, and earnings per share. How did these companies explain their revenue growth and profitability trends in their MD&A sections, and what supply chain or competitive risks did they highlight in their Risk Factors?
#
# [ENTITY EXTRACTION]
#   Companies: AAPL, AMZN, GOOGL, MSFT, TSLA
#   Years:     2018, 2019, 2020, 2021, 2022
#   Sections:  ITEM_1A, ITEM_7
#   Metrics:   Operating Cash Flow, Stockholders' Equity, Gross Profit, Debt-to-Assets, ROA % (Avg Assets), Revenue, Net Income
#
# [METRIC PIPELINE FILTERS]
#   Tickers: AAPL, AMZN, GOOGL, MSFT, TSLA
#   Years:   2018, 2019, 2020, 2021, 2022
#   Metrics: Operating Cash Flow, Stockholders' Equity, Gross Profit, Debt-to-Assets, ROA % (Avg Assets), Revenue, Net Income
#   Records returned: 109

# %%
## =================================================================================================
##  BUSINESS QUERY VALIDATION WITH SRC TABLE.
## =================================================================================================

from pathlib import Path
import sys
import polars as pl

# 1. Put ModelPipeline on sys.path
current = Path.cwd()
for parent in [current] + list(current.parents):
    if parent.name == "ModelPipeline":
        model_root = parent
        break
else:
    raise RuntimeError("Cannot find 'ModelPipeline' root in path tree")
if str(model_root) not in sys.path:
    sys.path.insert(0, str(model_root))
print(f"✓ Model root on sys.path: {model_root}")


# Set maximum rows to display (None = unlimited)
pl.Config.set_tbl_rows(-1)  # or pl.Config.set_tbl_rows(None)

# Set maximum columns to display
pl.Config.set_tbl_cols(-1)

# Set maximum string column width (characters)
pl.Config.set_fmt_str_lengths(1000)  # or higher like 5000

# Set table width (total console width)
pl.Config.set_tbl_width_chars(2000)

# Optional: Set float precision for numeric display
pl.Config.set_float_precision(3)


## SUPPLY LINE 1: ENTITY-RESULT CHAINING. DEMO. Query → Extract Entities → Validate/Embed → Get KPI Data → Format → Display
from finrag_ml_tg1.rag_modules_src.utilities.supply_line_formatters import format_analytical_compact
from finrag_ml_tg1.rag_modules_src.metric_pipeline.src.pipeline import MetricPipeline
from finrag_ml_tg1.rag_modules_src.entity_adapter.entity_adapter import EntityAdapter

METRIC_DATA_JSON = model_root / "finrag_ml_tg1/rag_modules_src/metric_pipeline/data/downloaded_data.json"
DIM_COMPANIES = model_root / "finrag_ml_tg1/data_cache/dimensions/finrag_dim_companies_21.parquet"
DIM_SECTIONS = model_root / "finrag_ml_tg1/data_cache/dimensions/finrag_dim_sec_sections.parquet"
METRIC_DATA_FACT = model_root / "finrag_ml_tg1/rag_modules_src/metric_pipeline/data/KPI_FACT_DATA_EDGAR.parquet" 

metric_fact_data_schema = pl.read_parquet(METRIC_DATA_FACT).collect_schema()
metric_fact_data_schema
metric_fact_data = pl.read_parquet(METRIC_DATA_FACT)


dist_tickers = metric_fact_data.select(pl.col("ticker").unique()).sort("ticker")
dist_tickers
# dist_companies = metric_fact_data.select(pl.col("company_name").unique()).sort("company_name")



# MSFT NVDA GOOGLE COST AMZN 
target_companies = ["MSFT", "NVDA", "GOOGL", "TSLA", "AAPL", "AMZN"]

metrics_view_readable = (
    metric_fact_data
    .filter(
        pl.col("ticker").is_in(target_companies) &
        pl.col("year").is_between(2018, 2022)
    )
    .select(["ticker", "metric_key",
              #, "metric_code", "metric_gaap",
              "metric_label", "year", "value"])
    .with_columns([
        # Add human-readable formatted column
        pl.when(pl.col("value").abs() >= 1e9)
          .then((pl.col("value") / 1e9).round(2).cast(pl.Utf8) + "B")
        .when(pl.col("value").abs() >= 1e6)
          .then((pl.col("value") / 1e6).round(2).cast(pl.Utf8) + "M")
        .when(pl.col("value").abs() >= 1e3)
          .then((pl.col("value") / 1e3).round(2).cast(pl.Utf8) + "K")
        .otherwise(pl.col("value").round(2).cast(pl.Utf8))
        .alias("value_readable")
    ])

    .filter( 
        pl.col("metric_label").is_in([
            "Operating Cash Flow", 
            "Gross Profit", 
            "Debt-to-Assets"
            ]) )
)


"""

AAPL:
  2018: Operating Cash Flow=$77.4B, Gross Profit=$24.1B, Debt-to-Assets=$1, ROA % (Avg Assets)=$17, Revenue=$62.9B, Net Income=$14.1B
  2019: Operating Cash Flow=$69.4B, Gross Profit=$24.3B, Debt-to-Assets=$1, ROA % (Avg Assets)=$17, Net Income=$13.7B
  2020: Operating Cash Flow=$80.7B, Gross Profit=$24.7B, Debt-to-Assets=$1, ROA % (Avg Assets)=$17, Net Income=$12.7B
  2021: Operating Cash Flow=$104.0B, Gross Profit=$152.8B, Debt-to-Assets=$1, ROA % (Avg Assets)=$27, Net Income=$94.7B
  2022: Operating Cash Flow=$122.2B, Gross Profit=$170.8B, Debt-to-Assets=$1, ROA % (Avg Assets)=$28, Net Income=$99.8B

AMZN:
  2018: Operating Cash Flow=$30.7B, ROA % (Avg Assets)=$5, Net Income=$3.0B
  2019: Operating Cash Flow=$38.5B, ROA % (Avg Assets)=$4, Net Income=$3.3B
  2020: Operating Cash Flow=$66.1B, ROA % (Avg Assets)=$6, Net Income=$7.2B
  2021: Operating Cash Flow=$46.3B, ROA % (Avg Assets)=$8, Net Income=$33.4B
  2022: Operating Cash Flow=$46.8B, ROA % (Avg Assets)=$-1, Net Income=$-2.7B

GOOGL:
  2018: Operating Cash Flow=$48.0B, Debt-to-Assets=$0, ROA % (Avg Assets)=$12, Net Income=$30.7B
  2019: Operating Cash Flow=$54.5B, Debt-to-Assets=$0, ROA % (Avg Assets)=$12, Net Income=$34.3B
  2020: Operating Cash Flow=$65.1B, Debt-to-Assets=$0, ROA % (Avg Assets)=$12, Revenue=$182.5B, Net Income=$40.3B
  2021: Operating Cash Flow=$91.7B, Debt-to-Assets=$0, ROA % (Avg Assets)=$21, Revenue=$257.6B, Net Income=$76.0B
  2022: Operating Cash Flow=$91.5B, Debt-to-Assets=$0, ROA % (Avg Assets)=$16, Net Income=$60.0B

MSFT:
  2018: Operating Cash Flow=$43.9B, Gross Profit=$20.3B, Debt-to-Assets=$1, ROA % (Avg Assets)=$6, Net Income=$8.9B
  2019: Operating Cash Flow=$52.2B, Gross Profit=$23.3B, Debt-to-Assets=$1, ROA % (Avg Assets)=$13, Net Income=$13.2B
  2020: Operating Cash Flow=$60.7B, Gross Profit=$25.7B, Debt-to-Assets=$1, ROA % (Avg Assets)=$14, Net Income=$11.2B
  2021: Operating Cash Flow=$76.7B, Gross Profit=$115.9B, Debt-to-Assets=$1, ROA % (Avg Assets)=$18, Net Income=$61.3B
  2022: Operating Cash Flow=$89.0B, Gross Profit=$135.6B, Debt-to-Assets=$1, ROA % (Avg Assets)=$19, Net Income=$72.7B

TSLA:
  2018: Operating Cash Flow=$2.1B, Gross Profit=$1.4B, Revenue=$7.2B
  2019: Operating Cash Flow=$2.4B, Gross Profit=$1.4B, Revenue=$7.4B
  2020: Operating Cash Flow=$5.9B, Gross Profit=$2.1B, Debt-to-Assets=$1, ROA % (Avg Assets)=$1, Revenue=$10.7B
  2021: Operating Cash Flow=$11.5B, Gross Profit=$13.6B, Debt-to-Assets=$0, ROA % (Avg Assets)=$8, Revenue=$53.8B
  2022: Operating Cash Flow=$14.7B, Gross Profit=$20.9B, Debt-to-Assets=$0, ROA % (Avg Assets)=$13, Revenue=$81.5B
"""

metrics_view_readable
# Out:
# ✓ Model root on sys.path: d:\JoelDesktop folds_24\NEU FALL2025\MLops IE7374 Project\FinSights\ModelPipeline
# shape: (73, 6)
# ┌────────┬────────────────┬─────────────────────┬──────────┬──────────────────┬────────────────┐
# │ ticker ┆ metric_key     ┆ metric_label        ┆ year     ┆ value            ┆ value_readable │
# │ ---    ┆ ---            ┆ ---                 ┆ ---      ┆ ---              ┆ ---            │
# │ str    ┆ str            ┆ str                 ┆ f64      ┆ f64              ┆ str            │
# ╞════════╪════════════════╪═════════════════════╪══════════╪══════════════════╪════════════════╡
# │ TSLA   ┆ cfo            ┆ Operating Cash Flow ┆ 2018.000 ┆ 2097802000.000   ┆ 2.1B           │
# │ TSLA   ┆ cfo            ┆ Operating Cash Flow ┆ 2019.000 ┆ 2405000000.000   ┆ 2.41B          │
# │ TSLA   ┆ cfo            ┆ Operating Cash Flow ┆ 2020.000 ┆ 5943000000.000   ┆ 5.94B          │
# │ TSLA   ┆ cfo            ┆ Operating Cash Flow ┆ 2021.000 ┆ 11497000000.000  ┆ 11.5B          │
# │ TSLA   ┆ cfo            ┆ Operating Cash Flow ┆ 2022.000 ┆ 14724000000.000  ┆ 14.72B         │
# │ TSLA   ┆ gross_profit   ┆ Gross Profit        ┆ 2018.000 ┆ 1442900000.000   ┆ 1.44B          │
# │ TSLA   ┆ gross_profit   ┆ Gross Profit        ┆ 2019.000 ┆ 1391000000.000   ┆ 1.39B          │
# │ TSLA   ┆ gross_profit   ┆ Gross Profit        ┆ 2020.000 ┆ 2066000000.000   ┆ 2.07B          │
# │ TSLA   ┆ gross_profit   ┆ Gross Profit        ┆ 2021.000 ┆ 13606000000.000  ┆ 13.61B         │
# │ TSLA   ┆ gross_profit   ┆ Gross Profit        ┆ 2022.000 ┆ 20853000000.000  ┆ 20.85B         │
# │ TSLA   ┆ debt_to_assets ┆ Debt-to-Assets      ┆ 2020.000 ┆ 0.545            ┆ 0.54           │
# │ TSLA   ┆ debt_to_assets ┆ Debt-to-Assets      ┆ 2021.000 ┆ 0.492            ┆ 0.49           │
# │ TSLA   ┆ debt_to_assets ┆ Debt-to-Assets      ┆ 2022.000 ┆ 0.443            ┆ 0.44           │
# │ AMZN   ┆ cfo            ┆ Operating Cash Flow ┆ 2018.000 ┆ 30723000000.000  ┆ 30.72B         │
# │ AMZN   ┆ cfo            ┆ Operating Cash Flow ┆ 2019.000 ┆ 38514000000.000  ┆ 38.51B         │
# │ AMZN   ┆ cfo            ┆ Operating Cash Flow ┆ 2020.000 ┆ 66064000000.000  ┆ 66.06B         │
# │ AMZN   ┆ cfo            ┆ Operating Cash Flow ┆ 2021.000 ┆ 46327000000.000  ┆ 46.33B         │
# │ AMZN   ┆ cfo            ┆ Operating Cash Flow ┆ 2022.000 ┆ 46752000000.000  ┆ 46.75B         │
# │ AAPL   ┆ cfo            ┆ Operating Cash Flow ┆ 2018.000 ┆ 77434000000.000  ┆ 77.43B         │
# │ AAPL   ┆ cfo            ┆ Operating Cash Flow ┆ 2019.000 ┆ 69391000000.000  ┆ 69.39B         │
# │ AAPL   ┆ cfo            ┆ Operating Cash Flow ┆ 2020.000 ┆ 80674000000.000  ┆ 80.67B         │
# │ AAPL   ┆ cfo            ┆ Operating Cash Flow ┆ 2021.000 ┆ 104038000000.000 ┆ 104.04B        │
# │ AAPL   ┆ cfo            ┆ Operating Cash Flow ┆ 2022.000 ┆ 122151000000.000 ┆ 122.15B        │
# │ AAPL   ┆ gross_profit   ┆ Gross Profit        ┆ 2018.000 ┆ 24084000000.000  ┆ 24.08B         │
# │ AAPL   ┆ gross_profit   ┆ Gross Profit        ┆ 2019.000 ┆ 24313000000.000  ┆ 24.31B         │
# │ AAPL   ┆ gross_profit   ┆ Gross Profit        ┆ 2020.000 ┆ 24689000000.000  ┆ 24.69B         │
# │ AAPL   ┆ gross_profit   ┆ Gross Profit        ┆ 2021.000 ┆ 152836000000.000 ┆ 152.84B        │
# │ AAPL   ┆ gross_profit   ┆ Gross Profit        ┆ 2022.000 ┆ 170782000000.000 ┆ 170.78B        │
# │ AAPL   ┆ debt_to_assets ┆ Debt-to-Assets      ┆ 2018.000 ┆ 0.707            ┆ 0.71           │
# │ AAPL   ┆ debt_to_assets ┆ Debt-to-Assets      ┆ 2019.000 ┆ 0.733            ┆ 0.73           │
# │ AAPL   ┆ debt_to_assets ┆ Debt-to-Assets      ┆ 2020.000 ┆ 0.798            ┆ 0.8            │
# │ AAPL   ┆ debt_to_assets ┆ Debt-to-Assets      ┆ 2021.000 ┆ 0.820            ┆ 0.82           │
# │ AAPL   ┆ debt_to_assets ┆ Debt-to-Assets      ┆ 2022.000 ┆ 0.856            ┆ 0.86           │
# │ NVDA   ┆ cfo            ┆ Operating Cash Flow ┆ 2018.000 ┆ 3502000000.000   ┆ 3.5B           │
# │ NVDA   ┆ cfo            ┆ Operating Cash Flow ┆ 2019.000 ┆ 3743000000.000   ┆ 3.74B          │
# │ NVDA   ┆ cfo            ┆ Operating Cash Flow ┆ 2020.000 ┆ 4761000000.000   ┆ 4.76B          │
# │ NVDA   ┆ cfo            ┆ Operating Cash Flow ┆ 2021.000 ┆ 5822000000.000   ┆ 5.82B          │
# │ NVDA   ┆ cfo            ┆ Operating Cash Flow ┆ 2022.000 ┆ 9108000000.000   ┆ 9.11B          │
# │ NVDA   ┆ gross_profit   ┆ Gross Profit        ┆ 2018.000 ┆ 1801000000.000   ┆ 1.8B           │
# │ NVDA   ┆ gross_profit   ┆ Gross Profit        ┆ 2019.000 ┆ 1207000000.000   ┆ 1.21B          │
# │ NVDA   ┆ gross_profit   ┆ Gross Profit        ┆ 2020.000 ┆ 2015000000.000   ┆ 2.02B          │
# │ NVDA   ┆ gross_profit   ┆ Gross Profit        ┆ 2021.000 ┆ 10396000000.000  ┆ 10.4B          │
# │ NVDA   ┆ gross_profit   ┆ Gross Profit        ┆ 2022.000 ┆ 17475000000.000  ┆ 17.48B         │
# │ NVDA   ┆ debt_to_assets ┆ Debt-to-Assets      ┆ 2018.000 ┆ 0.335            ┆ 0.34           │
# │ NVDA   ┆ debt_to_assets ┆ Debt-to-Assets      ┆ 2019.000 ┆ 0.297            ┆ 0.3            │
# │ NVDA   ┆ debt_to_assets ┆ Debt-to-Assets      ┆ 2020.000 ┆ 0.295            ┆ 0.3            │
# │ NVDA   ┆ debt_to_assets ┆ Debt-to-Assets      ┆ 2021.000 ┆ 0.413            ┆ 0.41           │
# │ NVDA   ┆ debt_to_assets ┆ Debt-to-Assets      ┆ 2022.000 ┆ 0.398            ┆ 0.4            │
# │ GOOGL  ┆ cfo            ┆ Operating Cash Flow ┆ 2018.000 ┆ 47971000000.000  ┆ 47.97B         │
# │ GOOGL  ┆ cfo            ┆ Operating Cash Flow ┆ 2019.000 ┆ 54520000000.000  ┆ 54.52B         │
# │ GOOGL  ┆ cfo            ┆ Operating Cash Flow ┆ 2020.000 ┆ 65124000000.000  ┆ 65.12B         │
# │ GOOGL  ┆ cfo            ┆ Operating Cash Flow ┆ 2021.000 ┆ 91652000000.000  ┆ 91.65B         │
# │ GOOGL  ┆ cfo            ┆ Operating Cash Flow ┆ 2022.000 ┆ 91495000000.000  ┆ 91.5B          │
# │ GOOGL  ┆ debt_to_assets ┆ Debt-to-Assets      ┆ 2018.000 ┆ 0.237            ┆ 0.24           │
# │ GOOGL  ┆ debt_to_assets ┆ Debt-to-Assets      ┆ 2019.000 ┆ 0.270            ┆ 0.27           │
# │ GOOGL  ┆ debt_to_assets ┆ Debt-to-Assets      ┆ 2020.000 ┆ 0.304            ┆ 0.3            │
# │ GOOGL  ┆ debt_to_assets ┆ Debt-to-Assets      ┆ 2021.000 ┆ 0.300            ┆ 0.3            │
# │ GOOGL  ┆ debt_to_assets ┆ Debt-to-Assets      ┆ 2022.000 ┆ 0.299            ┆ 0.3            │
# │ MSFT   ┆ cfo            ┆ Operating Cash Flow ┆ 2018.000 ┆ 43884000000.000  ┆ 43.88B         │
# │ MSFT   ┆ cfo            ┆ Operating Cash Flow ┆ 2019.000 ┆ 52185000000.000  ┆ 52.18B         │
# │ MSFT   ┆ cfo            ┆ Operating Cash Flow ┆ 2020.000 ┆ 60675000000.000  ┆ 60.68B         │
# │ MSFT   ┆ cfo            ┆ Operating Cash Flow ┆ 2021.000 ┆ 76740000000.000  ┆ 76.74B         │
# │ MSFT   ┆ cfo            ┆ Operating Cash Flow ┆ 2022.000 ┆ 89035000000.000  ┆ 89.04B         │
# │ MSFT   ┆ gross_profit   ┆ Gross Profit        ┆ 2018.000 ┆ 20343000000.000  ┆ 20.34B         │
# │ MSFT   ┆ gross_profit   ┆ Gross Profit        ┆ 2019.000 ┆ 23305000000.000  ┆ 23.3B          │
# │ MSFT   ┆ gross_profit   ┆ Gross Profit        ┆ 2020.000 ┆ 25694000000.000  ┆ 25.69B         │
# │ MSFT   ┆ gross_profit   ┆ Gross Profit        ┆ 2021.000 ┆ 115856000000.000 ┆ 115.86B        │
# │ MSFT   ┆ gross_profit   ┆ Gross Profit        ┆ 2022.000 ┆ 135620000000.000 ┆ 135.62B        │
# │ MSFT   ┆ debt_to_assets ┆ Debt-to-Assets      ┆ 2018.000 ┆ 0.680            ┆ 0.68           │
# │ MSFT   ┆ debt_to_assets ┆ Debt-to-Assets      ┆ 2019.000 ┆ 0.643            ┆ 0.64           │
# │ MSFT   ┆ debt_to_assets ┆ Debt-to-Assets      ┆ 2020.000 ┆ 0.607            ┆ 0.61           │
# │ MSFT   ┆ debt_to_assets ┆ Debt-to-Assets      ┆ 2021.000 ┆ 0.575            ┆ 0.57           │
# │ MSFT   ┆ debt_to_assets ┆ Debt-to-Assets      ┆ 2022.000 ┆ 0.544            ┆ 0.54           │
# └────────┴────────────────┴─────────────────────┴──────────┴──────────────────┴────────────────┘

# %% [markdown]
# ## Full diagnostic: Quick

# %%
# Full diagnostic
print("="*80)
print("DIAGNOSTIC CHECK")
print("="*80)

# 1. What metrics did extractor produce?
filters = metric_pipeline.extractor.extract(query)
print("\n1. Extracted Filters:")
print(f"   Tickers: {filters['tickers']}")
print(f"   Years: {filters['years']}")
print(f"   Metrics: {filters['metrics']}")

# 2. Do these exact values exist in parquet?
print("\n2. Data Availability:")
for ticker in filters['tickers']:
    for year in filters['years']:
        for metric in filters['metrics']:
            count = (
                metric_fact_data
                .filter(
                    (pl.col("ticker") == ticker) &
                    (pl.col("year") == float(year)) &  # Convert to float!
                    (pl.col("metric_label") == metric)
                )
                .height
            )
            if count > 0:
                print(f"   ✓ {ticker} | {year} | {metric}: {count} records")
            else:
                print(f"   ✗ {ticker} | {year} | {metric}: NOT FOUND")

# 3. Show sample of what IS available
print("\n3. Sample Available Data:")
sample = (
    metric_fact_data
    .filter(pl.col("ticker").is_in(filters['tickers']))
    .filter(pl.col("year").is_in([float(y) for y in filters['years']]))
    .select(["ticker", "year", "metric_label"])
    .unique()
    .head(20)
)
print(sample)
# Out:
# ================================================================================
# DIAGNOSTIC CHECK
# ================================================================================
#
# 1. Extracted Filters:
#    Tickers: ['AAPL', 'AMZN', 'GOOGL', 'MSFT', 'TSLA']
#    Years: [2018, 2019, 2020, 2021, 2022]
#    Metrics: ["Stockholders' Equity", 'ROA % (Avg Assets)', 'Revenue', 'Net Income']
#
# 2. Data Availability:
#    ✗ AAPL | 2018 | Stockholders' Equity: NOT FOUND
#    ✓ AAPL | 2018 | ROA % (Avg Assets): 1 records
#    ✓ AAPL | 2018 | Revenue: 1 records
#    ✓ AAPL | 2018 | Net Income: 1 records
#    ✗ AAPL | 2019 | Stockholders' Equity: NOT FOUND
#    ✓ AAPL | 2019 | ROA % (Avg Assets): 1 records
#    ✗ AAPL | 2019 | Revenue: NOT FOUND
#    ✓ AAPL | 2019 | Net Income: 1 records
#    ✗ AAPL | 2020 | Stockholders' Equity: NOT FOUND
#    ✓ AAPL | 2020 | ROA % (Avg Assets): 1 records
#    ✗ AAPL | 2020 | Revenue: NOT FOUND
#    ✓ AAPL | 2020 | Net Income: 1 records
#    ✗ AAPL | 2021 | Stockholders' Equity: NOT FOUND
#    ✓ AAPL | 2021 | ROA % (Avg Assets): 1 records
#    ✗ AAPL | 2021 | Revenue: NOT FOUND
#    ✓ AAPL | 2021 | Net Income: 1 records
#    ✗ AAPL | 2022 | Stockholders' Equity: NOT FOUND
#    ✓ AAPL | 2022 | ROA % (Avg Assets): 1 records
#    ✗ AAPL | 2022 | Revenue: NOT FOUND
#    ✓ AAPL | 2022 | Net Income: 1 records
#    ✗ AMZN | 2018 | Stockholders' Equity: NOT FOUND
#    ✓ AMZN | 2018 | ROA % (Avg Assets): 1 records
#    ✗ AMZN | 2018 | Revenue: NOT FOUND
#    ✓ AMZN | 2018 | Net Income: 1 records
#    ✗ AMZN | 2019 | Stockholders' Equity: NOT FOUND
#    ✓ AMZN | 2019 | ROA % (Avg Assets): 1 records
#    ✗ AMZN | 2019 | Revenue: NOT FOUND
#    ✓ AMZN | 2019 | Net Income: 1 records
#    ✗ AMZN | 2020 | Stockholders' Equity: NOT FOUND
#    ✓ AMZN | 2020 | ROA % (Avg Assets): 1 records
#    ✗ AMZN | 2020 | Revenue: NOT FOUND
#    ✓ AMZN | 2020 | Net Income: 1 records
#    ✗ AMZN | 2021 | Stockholders' Equity: NOT FOUND
#    ✓ AMZN | 2021 | ROA % (Avg Assets): 1 records
#    ✗ AMZN | 2021 | Revenue: NOT FOUND
#    ✓ AMZN | 2021 | Net Income: 1 records
#    ✗ AMZN | 2022 | Stockholders' Equity: NOT FOUND
#    ✓ AMZN | 2022 | ROA % (Avg Assets): 1 records
#    ✗ AMZN | 2022 | Revenue: NOT FOUND
#    ✓ AMZN | 2022 | Net Income: 1 records
#    ✗ GOOGL | 2018 | Stockholders' Equity: NOT FOUND
#    ✓ GOOGL | 2018 | ROA % (Avg Assets): 1 records
#    ✗ GOOGL | 2018 | Revenue: NOT FOUND
#    ✓ GOOGL | 2018 | Net Income: 1 records
#    ✗ GOOGL | 2019 | Stockholders' Equity: NOT FOUND
#    ✓ GOOGL | 2019 | ROA % (Avg Assets): 1 records
#    ✗ GOOGL | 2019 | Revenue: NOT FOUND
#    ✓ GOOGL | 2019 | Net Income: 1 records
#    ✗ GOOGL | 2020 | Stockholders' Equity: NOT FOUND
#    ✓ GOOGL | 2020 | ROA % (Avg Assets): 1 records
#    ✓ GOOGL | 2020 | Revenue: 1 records
#    ✓ GOOGL | 2020 | Net Income: 1 records
#    ✗ GOOGL | 2021 | Stockholders' Equity: NOT FOUND
#    ✓ GOOGL | 2021 | ROA % (Avg Assets): 1 records
#    ✓ GOOGL | 2021 | Revenue: 1 records
#    ✓ GOOGL | 2021 | Net Income: 1 records
#    ✗ GOOGL | 2022 | Stockholders' Equity: NOT FOUND
#    ✓ GOOGL | 2022 | ROA % (Avg Assets): 1 records
#    ✗ GOOGL | 2022 | Revenue: NOT FOUND
#    ✓ GOOGL | 2022 | Net Income: 1 records
#    ✗ MSFT | 2018 | Stockholders' Equity: NOT FOUND
#    ✓ MSFT | 2018 | ROA % (Avg Assets): 1 records
#    ✗ MSFT | 2018 | Revenue: NOT FOUND
#    ✓ MSFT | 2018 | Net Income: 1 records
#    ✗ MSFT | 2019 | Stockholders' Equity: NOT FOUND
#    ✓ MSFT | 2019 | ROA % (Avg Assets): 1 records
#    ✗ MSFT | 2019 | Revenue: NOT FOUND
#    ✓ MSFT | 2019 | Net Income: 1 records
#    ✗ MSFT | 2020 | Stockholders' Equity: NOT FOUND
#    ✓ MSFT | 2020 | ROA % (Avg Assets): 1 records
#    ✗ MSFT | 2020 | Revenue: NOT FOUND
#    ✓ MSFT | 2020 | Net Income: 1 records
#    ✗ MSFT | 2021 | Stockholders' Equity: NOT FOUND
#    ✓ MSFT | 2021 | ROA % (Avg Assets): 1 records
#    ✗ MSFT | 2021 | Revenue: NOT FOUND
#    ✓ MSFT | 2021 | Net Income: 1 records
#    ✗ MSFT | 2022 | Stockholders' Equity: NOT FOUND
#    ✓ MSFT | 2022 | ROA % (Avg Assets): 1 records
#    ✗ MSFT | 2022 | Revenue: NOT FOUND
#    ✓ MSFT | 2022 | Net Income: 1 records
#    ✗ TSLA | 2018 | Stockholders' Equity: NOT FOUND
#    ✗ TSLA | 2018 | ROA % (Avg Assets): NOT FOUND
#    ✓ TSLA | 2018 | Revenue: 1 records
#    ✗ TSLA | 2018 | Net Income: NOT FOUND
#    ✗ TSLA | 2019 | Stockholders' Equity: NOT FOUND
#    ✗ TSLA | 2019 | ROA % (Avg Assets): NOT FOUND
#    ✓ TSLA | 2019 | Revenue: 1 records
#    ✗ TSLA | 2019 | Net Income: NOT FOUND
#    ✗ TSLA | 2020 | Stockholders' Equity: NOT FOUND
#    ✓ TSLA | 2020 | ROA % (Avg Assets): 1 records
#    ✓ TSLA | 2020 | Revenue: 1 records
#    ✗ TSLA | 2020 | Net Income: NOT FOUND
#    ✗ TSLA | 2021 | Stockholders' Equity: NOT FOUND
#    ✓ TSLA | 2021 | ROA % (Avg Assets): 1 records
#    ✓ TSLA | 2021 | Revenue: 1 records
#    ✗ TSLA | 2021 | Net Income: NOT FOUND
#    ✗ TSLA | 2022 | Stockholders' Equity: NOT FOUND
#    ✓ TSLA | 2022 | ROA % (Avg Assets): 1 records
#    ✓ TSLA | 2022 | Revenue: 1 records
#    ✗ TSLA | 2022 | Net Income: NOT FOUND
#
# 3. Sample Available Data:
# shape: (20, 3)
# ┌────────┬──────────┬───────────────────────────────────────────────┐
# │ ticker ┆ year     ┆ metric_label                                  │
# │ ---    ┆ ---      ┆ ---                                           │
# │ str    ┆ f64      ┆ str                                           │
# ╞════════╪══════════╪═══════════════════════════════════════════════╡
# │ MSFT   ┆ 2020.000 ┆ Liabilities & Stockholders’ Equity            │
# │ MSFT   ┆ 2021.000 ┆ ROA % (Avg Assets)                            │
# │ AAPL   ┆ 2018.000 ┆ Net Profit Margin %                           │
# │ TSLA   ┆ 2018.000 ┆ Deferred Tax Asset Valuation Allowance Change │
# │ TSLA   ┆ 2018.000 ┆ Amortization Expense – Year 5                 │
# │ MSFT   ┆ 2019.000 ┆ Operating Cash Flow                           │
# │ AAPL   ┆ 2021.000 ┆ Net Income                                    │
# │ MSFT   ┆ 2019.000 ┆ Other Assets (Noncurrent)                     │
# │ GOOGL  ┆ 2022.000 ┆ Other Current Assets                          │
# │ TSLA   ┆ 2019.000 ┆ Deferred Tax Assets – Deferred Income         │
# │ AMZN   ┆ 2018.000 ┆ Employee-Related Liabilities (Total)          │
# │ GOOGL  ┆ 2022.000 ┆ Other Accrued Liabilities (Current)           │
# │ TSLA   ┆ 2022.000 ┆ Revenue                                       │
# │ GOOGL  ┆ 2019.000 ┆ Stockholders’ Equity                          │
# │ MSFT   ┆ 2022.000 ┆ Debt-to-Assets                                │
# │ GOOGL  ┆ 2019.000 ┆ VIE Assets Pledged                            │
# │ GOOGL  ┆ 2022.000 ┆ Intangible Assets (Gross, Excluding Goodwill) │
# │ MSFT   ┆ 2019.000 ┆ Gross Profit                                  │
# │ AMZN   ┆ 2021.000 ┆ Employee-Related Liabilities (Current)        │
# │ AMZN   ┆ 2022.000 ┆ Deferred Tax Asset Valuation Allowance Change │
# └────────┴──────────┴───────────────────────────────────────────────┘
